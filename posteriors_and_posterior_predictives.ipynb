# %% [markdown]
# This file plots the priors and posteriors from ABC simulations already computed and data already saved.

# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import data_preprocessing.plotting_functions as ABC_plot
import data_preprocessing.data_preprocessing as data

SMALL_SIZE = 12
MEDIUM_SIZE = 12
BIGGER_SIZE = 16

plt.rc('font', size=BIGGER_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.rcParams['font.family'] = 'Arial'

# %% [markdown]
# Import ABC data

# %%
all_pulse_params = np.load("./data_preprocessing/simulated_ABC_data/pulse/extended_three_population_pulse_params.npy")
accepted_pulse_params = np.load("./data_preprocessing/simulated_ABC_data/pulse/accepted_extended_three_population_pulse_params.npy")
all_chase_pulse_params = np.load("./data_preprocessing/simulated_ABC_data/chase/extended_three_population_chase_pulse_params.npy")
accepted_chase_pulse_params = np.load("./data_preprocessing/simulated_ABC_data/chase/accepted_extended_three_population_chase_pulse_params.npy")
all_chase_chase_params = np.load("./data_preprocessing/simulated_ABC_data/chase/extended_three_population_chase_chase_params.npy")
accepted_chase_chase_params = np.load("./data_preprocessing/simulated_ABC_data/chase/accepted_extended_three_population_chase_chase_params.npy")

# %% [markdown]
# 1 dimensional pulse posteriors

# %%
ABC_plot.extended_three_population_posteriors(all_pulse_params, accepted_pulse_params, all_chase_pulse_params, accepted_chase_pulse_params, all_chase_chase_params, accepted_chase_chase_params, mode = "pulse", dimensions = 1, MAP = False, death_mode = 0)

# %% [markdown]
# 2 dimensional pulse posteriors

# %%
ABC_plot.extended_three_population_posteriors(all_pulse_params, accepted_pulse_params, all_chase_pulse_params, accepted_chase_pulse_params, all_chase_chase_params, accepted_chase_chase_params, mode = "pulse", dimensions = 2, MAP = False, death_mode = 0)
# Out:
# pulse plot

# %% [markdown]
# 1 dimensional pulse-chase posteriors

# %%
ABC_plot.extended_three_population_posteriors(all_pulse_params, accepted_pulse_params, all_chase_pulse_params, accepted_chase_pulse_params, all_chase_chase_params, accepted_chase_chase_params, mode = "chase", dimensions = 1, MAP = False, death_mode = 0)

# %% [markdown]
# 2 dimensional pulse-chase posteriors

# %%
ABC_plot.extended_three_population_posteriors(all_pulse_params, accepted_pulse_params, all_chase_pulse_params, accepted_chase_pulse_params, all_chase_chase_params, accepted_chase_chase_params, mode = "chase", dimensions = 2, MAP = False, death_mode = 0)
# Out:
# chase

# %% [markdown]
# mu_b posterior

# %%
ABC_plot.mu_b_posterior(accepted_chase_pulse_params)

# %% [markdown]
# Degradation mode posterior

# %%
ABC_plot.death_mode_posterior(all_chase_pulse_params, accepted_chase_pulse_params)

# %% [markdown]
# Subpopulation proportions posterior

# %%
ABC_plot.population_proportions(accepted_chase_pulse_params)

# %% [markdown]
# Parameter-coalescent rate correlations

# %%
ABC_plot.parameter_coalescent_correlations(accepted_chase_pulse_params)

# %% [markdown]
# Importing pulse cells posterior predictive simulations

# %%
pulse_val_varstat = np.load("./data_preprocessing/simulated_posterior_predictive_data/pulse/val/pulse_val_varstat.npy")
pulse_val_edu_traj = np.load("./data_preprocessing/simulated_posterior_predictive_data/pulse/val/pulse_val_edu_traj.npy")
pulse_val_dna_traj = np.load("./data_preprocessing/simulated_posterior_predictive_data/pulse/val/pulse_val_dna_traj.npy")
pulse_val_peak1 = np.load("./data_preprocessing/simulated_posterior_predictive_data/pulse/val/pulse_val_peak1.npy")

pulse_train_varstat = np.load("./data_preprocessing/simulated_posterior_predictive_data/pulse/train/pulse_train_varstat.npy")
pulse_train_edu_traj = np.load("./data_preprocessing/simulated_posterior_predictive_data/pulse/train/pulse_train_edu_traj.npy")
pulse_train_dna_traj = np.load("./data_preprocessing/simulated_posterior_predictive_data/pulse/train/pulse_train_dna_traj.npy")
pulse_train_peak1 = np.load("./data_preprocessing/simulated_posterior_predictive_data/pulse/train/pulse_train_peak1.npy")

# %% [markdown]
# Training pulse cells posterior predictive

# %%
ABC_plot.single_posterior_predictive_pulse(pulse_train_dna_traj, pulse_train_edu_traj, pulse_train_peak1, pulse_train_varstat, mode = "training")

# %% [markdown]
# Validation pulse cells posterior predictive

# %%
ABC_plot.single_posterior_predictive_pulse(pulse_val_dna_traj, pulse_val_edu_traj, pulse_val_peak1, pulse_val_varstat, mode = "validation")

# %% [markdown]
# Importing pulse-chase cells posterior predicitive simulations

# %%
chase_val_varstat = np.load("./data_preprocessing/simulated_posterior_predictive_data/chase/val/chase_val_varstat.npy")
chase_val_edu_traj = np.load("./data_preprocessing/simulated_posterior_predictive_data/chase/val/chase_val_edu_traj.npy")
chase_val_dna_traj = np.load("./data_preprocessing/simulated_posterior_predictive_data/chase/val/chase_val_dna_traj.npy")
chase_val_edu_prop = np.load("./data_preprocessing/simulated_posterior_predictive_data/chase/val/chase_val_edu_prop.npy")
chase_val_peak1_0dy = np.load("./data_preprocessing/simulated_posterior_predictive_data/chase/val/chase_val_peak1_0dy.npy")
chase_val_peak1_4dy = np.load("./data_preprocessing/simulated_posterior_predictive_data/chase/val/chase_val_peak1_4dy.npy")

chase_train_varstat = np.load("./data_preprocessing/simulated_posterior_predictive_data/chase/train/chase_train_varstat.npy")
chase_train_edu_traj = np.load("./data_preprocessing/simulated_posterior_predictive_data/chase/train/chase_train_edu_traj.npy")
chase_train_dna_traj = np.load("./data_preprocessing/simulated_posterior_predictive_data/chase/train/chase_train_dna_traj.npy")
chase_train_edu_prop = np.load("./data_preprocessing/simulated_posterior_predictive_data/chase/train/chase_train_edu_prop.npy")
chase_train_peak1_0dy = np.load("./data_preprocessing/simulated_posterior_predictive_data/chase/train/chase_train_peak1_0dy.npy")
chase_train_peak1_4dy = np.load("./data_preprocessing/simulated_posterior_predictive_data/chase/train/chase_train_peak1_4dy.npy")

# %% [markdown]
# Training pulse-chase cells posterior predictive

# %%
ABC_plot.single_posterior_predictive_chase(chase_train_dna_traj, chase_train_edu_traj, chase_train_edu_prop, chase_train_peak1_0dy, chase_train_peak1_4dy, chase_train_varstat, mode = "training")

# %% [markdown]
# Validation pulse-chase cells posterior predictive

# %%
ABC_plot.single_posterior_predictive_chase(chase_val_dna_traj, chase_val_edu_traj, chase_val_edu_prop, chase_val_peak1_0dy, chase_val_peak1_4dy, chase_val_varstat, mode = "validation")

# %% [markdown]
# Validation ABC distances

# %%
pulse_train_distances = np.load("./data_preprocessing/simulated_posterior_predictive_data/pulse/train/pulse_train_distances.npy")
pulse_val_distances = np.load("./data_preprocessing/simulated_posterior_predictive_data/pulse/val/pulse_val_distances.npy")
chase_train_distances = np.load("./data_preprocessing/simulated_posterior_predictive_data/chase/train/chase_train_distances.npy")
chase_val_distances= np.load("./data_preprocessing/simulated_posterior_predictive_data/chase/val/chase_val_distances.npy")

ABC_plot.ABC_validation_distances(pulse_train_distances, pulse_val_distances, chase_train_distances, chase_val_distances)
